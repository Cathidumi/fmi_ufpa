# %% [markdown]
# <a href="https://colab.research.google.com/github/Cathidumi/fmi_ufpa/blob/main/TestesARIMA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ARIMA
# ## Carrega o arquivo

# %%
import pandas as pd
import pandas.util.testing as tm
from matplotlib import pyplot
from pandas import DataFrame
from numpy import sqrt
from sklearn.metrics import mean_squared_error
from pandas.plotting import autocorrelation_plot
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.arima_model import ARIMA

from google.colab import drive
drive.mount('/content/drive')
# Elimina os warnings das bibliotecas
# import warnings
# warnings.filterwarnings("ignore")

# %%
sCaminho = '/content/drive/MyDrive/dados_new3.csv'
#dfDados = pd.read_csv(sCaminho, usecols=['INS', 'HR_MED', 'TEM_INS', 'UMD_INS', 'VEN_VEL'], parse_dates=['INS'])
dfDados = pd.read_csv(sCaminho, usecols=['INS', 'TEM_INS'], parse_dates=['INS'])
dfDados

# %% [markdown]
# # Teste 1

# %%
dfTeste1 = pd.read_csv(sCaminho, usecols=['INS', 'TEM_INS'], parse_dates=['INS'])
dfTeste1.set_index('INS', inplace=True)
dfTeste1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 88080 entries, 2012-01-01 00:00:00 to 2022-01-17 23:00:00
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   TEM_INS  88080 non-null  float64
# dtypes: float64(1)
# memory usage: 1.3 MB

# %%
model = ARIMA(dfTeste1, order=(24,1,1))

# %%
model_fit = model.fit()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-a0e793f6305e> in <module>()
# ----> 1 model_fit = model.fit()
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/arima_model.py in fit(self, start_params, trend, method, transparams, solver, maxiter, full_output, disp, callback, start_ar_lags, **kwargs)
#    1147                                            method, transparams, solver,
#    1148                                            maxiter, full_output, disp,
# -> 1149                                            callback, start_ar_lags, **kwargs)
#    1150         normalized_cov_params = None  # TODO: fix this?
#    1151         arima_fit = ARIMAResults(self, mlefit._results.params,
#
# ...

# %% [markdown]
# # Teste 2

# %%
dfTeste2 = pd.read_csv(sCaminho, usecols=['INS', 'TEM_INS', 'UMD_INS', 'VEN_VEL'], parse_dates=['INS'])
# dfTeste2.head()
dfTeste2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88080 entries, 0 to 88079
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   INS      88080 non-null  datetime64[ns]
#  1   TEM_INS  88080 non-null  float64
#  2   VEN_VEL  88080 non-null  float64
#  3   UMD_INS  88080 non-null  float64
# dtypes: datetime64[ns](1), float64(3)
# memory usage: 2.7 MB

# %%
dfTeste2.set_index('INS', inplace=True)

# %%
dfTeste2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 88080 entries, 2012-01-01 00:00:00 to 2022-01-17 23:00:00
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   TEM_INS  88080 non-null  float64
#  1   VEN_VEL  88080 non-null  float64
#  2   UMD_INS  88080 non-null  float64
# dtypes: float64(3)
# memory usage: 2.7 MB

# %%
dfTeste2.plot(figsize = (20,6))
