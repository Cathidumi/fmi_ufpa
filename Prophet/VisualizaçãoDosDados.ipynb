# %% [markdown]
# <a href="https://colab.research.google.com/github/Cathidumi/fmi_ufpa/blob/main/Prophet/Visualiza%C3%A7%C3%A3oDosDados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Arquivo feito pra visualização dos dados dos últimos 5 dias até 07/01/2022

# %%
import pandas as pd

anual = 'Dados um ano.csv'
mensal = 'Dados um mes.csv'

# Lê o .csv com os dados base
dados = pd.read_csv(mensal, usecols=['INS', 'HORA', 'TEM_INS', 'UMD_INS', 'VEN_VEL'], parse_dates=['INS'])
dados
# Out:
#                     INS  HORA  TEM_INS  VEN_VEL  UMD_INS
# 0   2021-12-01 00:00:00     0     27.0      0.3     83.0
# 1   2021-12-01 01:00:00     1     27.0      0.6     85.0
# 2   2021-12-01 02:00:00     2     27.0      0.5     87.0
# 3   2021-12-01 03:00:00     3     26.6      0.3     88.0
# 4   2021-12-01 04:00:00     4     26.6      0.1     88.0
# ..                  ...   ...      ...      ...      ...
# 907 2022-01-07 19:00:00    19     27.2      0.2     83.0
# 908 2022-01-07 20:00:00    20     26.8      0.6     86.0
# 909 2022-01-07 21:00:00    21     26.7      0.9     87.0
# 910 2022-01-07 22:00:00    22     26.1      1.4     90.0
# 911 2022-01-07 23:00:00    23     25.8      1.7     90.0
#
# [912 rows x 5 columns]

# %%
# Importar dados para um DataFrame
df = pd.read_csv(mensal, usecols=['INS', 'TEM_INS'], parse_dates=['INS'])
df.rename(columns={'INS': 'ds', 'TEM_INS': 'y'}, inplace = True)

# %%
df.sort_values('ds', inplace=True)
df.set_index('ds', inplace=True)
df.plot()

# %%
for c in range(24):
  teste = dados[dados['HORA'] == c]
  teste.to_csv('HORA/HORA'+str(c)+'.csv', index=False)

# %%
# TEMPERATURA

for c in range(24):
  temp0 = pd.read_csv('HORA/HORA'+str(c)+'.csv', usecols=['INS', 'TEM_INS'], parse_dates=['INS'])
  temp0.rename(columns={'INS': 'ds', 'TEM_INS': 'y'}, inplace = True)

  temp0.sort_values('ds', inplace=True)
  temp0.set_index('ds', inplace=True)
  temp0.plot(title=c)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/core.py:328: RuntimeWarning:
#
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/core.py:328: RuntimeWarning:
#
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/core.py:328: RuntimeWarning:
#
# ...

# %%
# UMIDADE

for c in range(24):
  temp0 = pd.read_csv('HORA/HORA'+str(c)+'.csv', usecols=['INS', 'UMD_INS'], parse_dates=['INS'])
  temp0.rename(columns={'INS': 'ds', 'UMD_INS': 'y'}, inplace = True)

  temp0.sort_values('ds', inplace=True)
  temp0.set_index('ds', inplace=True)
  temp0.plot(title=c)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/core.py:328: RuntimeWarning:
#
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/core.py:328: RuntimeWarning:
#
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/core.py:328: RuntimeWarning:
#
# ...

# %%
# VELOCIDADE DO VENTO

for c in range(24):
  temp0 = pd.read_csv('HORA/HORA'+str(c)+'.csv', usecols=['INS', 'VEN_VEL'], parse_dates=['INS'])
  temp0.rename(columns={'INS': 'ds', 'VEN_VEL': 'y'}, inplace = True)

  temp0.sort_values('ds', inplace=True)
  temp0.set_index('ds', inplace=True)
  temp0.plot(title=c)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/core.py:328: RuntimeWarning:
#
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/core.py:328: RuntimeWarning:
#
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/core.py:328: RuntimeWarning:
#
# ...
